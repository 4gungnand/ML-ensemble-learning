# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# load cleaned data
df = pd.read_csv('marketing_campaign.csv')

pd.options.display.max_columns = 100

# %%
df.iloc[0:10]
# Out:
#                                  From                        To  \
# 0             quincy@freecodecamp.org  premananda2003@gmail.com
# 1                  updates@myntra.com  premananda2003@gmail.com
# 2                    hello@medium.com  premananda2003@gmail.com
# 3  do_not_reply@mailersp1.binance.com  premananda2003@gmail.com
# 4                 news@info.avira.com  premananda2003@gmail.com
# 5        no-reply@accounts.google.com  premananda2003@gmail.com
# 6                      mipa@ugm.ac.id  premananda2003@gmail.com
# 7              hello@thestudent.world  premananda2003@gmail.com
# 8        welcome@insanbumimandiri.org  premananda2003@gmail.com
# 9                   noreply@ovo.co.id  premananda2003@gmail.com
#
#                                              Subject  \
# 0  learn code apps chatgpt dall free hour javascr...
# 1  myntra order item delivered please share feedback
# 2                    japanese website look different
# ...

# %%
print(df.shape)
# Out:
# (1160, 8)

# %%
# Remove extra white space in label
df['Label'] = df['Label'].str.strip()

# %%
# Take the only first label
df['Label'] = df['Label'].str.split(' ').str[0]

print(df.shape)
# Out:
# (1160, 8)

# %%
df.iloc[0:10]
# Out:
#                                  From                        To  \
# 0             quincy@freecodecamp.org  premananda2003@gmail.com
# 1                  updates@myntra.com  premananda2003@gmail.com
# 2                    hello@medium.com  premananda2003@gmail.com
# 3  do_not_reply@mailersp1.binance.com  premananda2003@gmail.com
# 4                 news@info.avira.com  premananda2003@gmail.com
# 5        no-reply@accounts.google.com  premananda2003@gmail.com
# 6                      mipa@ugm.ac.id  premananda2003@gmail.com
# 7              hello@thestudent.world  premananda2003@gmail.com
# 8        welcome@insanbumimandiri.org  premananda2003@gmail.com
# 9                   noreply@ovo.co.id  premananda2003@gmail.com
#
#                                              Subject  \
# 0  learn code apps chatgpt dall free hour javascr...
# 1  myntra order item delivered please share feedback
# 2                    japanese website look different
# ...

# %%
# Plot the distribution of the Label column
df['Label'].value_counts().plot(kind='bar', title='Label distribution')
# Out:
# <Axes: title={'center': 'Label distribution'}, xlabel='Label'>

# %%
# Remove rows with label spam, travel, study, and abroad
df = df[~df['Label'].isin(['travel', 'study', 'abroad'])]
print(df.shape)
# Out:
# (1158, 8)

# %%
df.iloc[28:39]
# Out:
#                                         From                        To  \
# 28           netacademail@external.cisco.com  premananda2003@gmail.com
# 29               no-reply@hackerrankmail.com  premananda2003@gmail.com
# 30                        info@typeracer.com  premananda2003@gmail.com
# 31              worldhistory-space@quora.com  premananda2003@gmail.com
# 32              welcome@insanbumimandiri.org  premananda2003@gmail.com
# 33        notifications-noreply@linkedin.com  premananda2003@gmail.com
# 34                  info@collegeessayguy.com  premananda2003@gmail.com
# 35                        hello@gramedia.com  premananda2003@gmail.com
# 36  indonesian-personalized-digest@quora.com  premananda2003@gmail.com
# 37                                       NaN  premananda2003@gmail.com
# 38                          edx@news.edx.org  premananda2003@gmail.com
#
#                                               Subject  \
# 28                        five lucky winner could one
# ...

# %%
# Drop the month and year columns 
df = df.drop(['Month', 'Year'], axis=1)

df.iloc[0:10]
# Out:
#                                  From                        To  \
# 0             quincy@freecodecamp.org  premananda2003@gmail.com
# 1                  updates@myntra.com  premananda2003@gmail.com
# 2                    hello@medium.com  premananda2003@gmail.com
# 3  do_not_reply@mailersp1.binance.com  premananda2003@gmail.com
# 4                 news@info.avira.com  premananda2003@gmail.com
# 5        no-reply@accounts.google.com  premananda2003@gmail.com
# 6                      mipa@ugm.ac.id  premananda2003@gmail.com
# 7              hello@thestudent.world  premananda2003@gmail.com
# 8        welcome@insanbumimandiri.org  premananda2003@gmail.com
# 9                   noreply@ovo.co.id  premananda2003@gmail.com
#
#                                              Subject  \
# 0  learn code apps chatgpt dall free hour javascr...
# 1  myntra order item delivered please share feedback
# 2                    japanese website look different
# ...

# %%
# Print all the unique values in the "To" column
df['To'].unique()
# Out:
# array(['premananda2003@gmail.com',
#        'ifiadventurethe-1716@pages.plusgoogle.com',
#        'welcomenetevent@gmail.com', 'fikriyahhr@gmail.com',
#        'premananda2003@gmail.com, premananda2003@gmail.com',
#        'careercenter@karirlab.co', 'katsumata.kazuto.gf@un.tsukuba.ac.jp',
#        'irving.louis.fb@u.tsukuba.ac.jp, sakurai@bk.tsukuba.ac.jp, islam.monir.ke@u.tsukuba.ac.jp, islam.monir.ke@u.tsukuba.ac.jp, vasilache.simona.gm@u.tsukuba.ac.jp, sandoval.felipe.ga@u.tsukuba.ac.jp, sandoval.felipe.ga@u.tsukuba.ac.jp, shimpo.naomi.gn@u.tsukuba.ac.jp',
# ...

# %%
print(df.shape)
# Out:
# (1158, 6)

# %%
# Drop nan values
df = df.dropna()

# %%
# Search for the word 'premananda2003@gmail.com' in To column
df[df['To'].str.contains('premananda2003@gmail.com')]
# Out:
#                                           From                        To  \
# 0                      quincy@freecodecamp.org  premananda2003@gmail.com
# 1                           updates@myntra.com  premananda2003@gmail.com
# 2                             hello@medium.com  premananda2003@gmail.com
# 3           do_not_reply@mailersp1.binance.com  premananda2003@gmail.com
# 4                          news@info.avira.com  premananda2003@gmail.com
# ...                                        ...                       ...
# 1155  indonesian-personalized-digest@quora.com  premananda2003@gmail.com
# 1156               updates@mp1.tripadvisor.com  premananda2003@gmail.com
# 1157  indonesian-personalized-digest@quora.com  premananda2003@gmail.com
# 1158                  noreply@steampowered.com  premananda2003@gmail.com
# 1159                  noreply@steampowered.com  premananda2003@gmail.com
#
#                                                 Subject  \
# ...

# %%
# Only keep the row that have to value of 'premananda2003 @gmail.com' or 'Premananda2003@gmail.com'
df = df[df['To'].str.contains('premananda2003@gmail.com')]

# %%
# Drop the to column
df = df.drop(['To'], axis=1)

# %%
# Print all the unique values in the Label column
df['Label'].unique()
# Out:
# array(['updates', 'spam', 'promotions', 'personal', 'social'],
#       dtype=object)

# %%
# # Create numerical values for the Label column
# df['Label'] = df['Label'].map({'updates':0, 'spam':1, 'promotions':2, 'personal':3, 'social':4})

# %%
# Print all the unique values in the from column
df['From'].unique()
# Out:
# array(['quincy@freecodecamp.org', 'updates@myntra.com',
#        'hello@medium.com', 'do_not_reply@mailersp1.binance.com',
#        'news@info.avira.com', 'no-reply@accounts.google.com',
#        'mipa@ugm.ac.id', 'hello@thestudent.world',
#        'welcome@insanbumimandiri.org', 'noreply@ovo.co.id',
#        'info@collegeessayguy.com', 'donasi@sedekahmasjid.com',
#        'hello@gramedia.com', 'no-reply@mangarock.com',
#        'support@kitabisa.com', 'learn@itr.mail.codecademy.com',
#        'indonesian-personalized-digest@quora.com',
#        'no-reply@members.babbel.com', 'inspiration@mp1.tripadvisor.com',
#        'marketing@hackthebox.com', 'security@facebookmail.com',
#        'adminland-space@quora.com', 'netacademail@external.cisco.com',
#        'no-reply@hackerrankmail.com', 'info@typeracer.com',
#        'worldhistory-space@quora.com',
#        'notifications-noreply@linkedin.com', 'edx@news.edx.org',
#        'taco@trello.com', 'invitations@linkedin.com',
# ...

# %%
# Take only the string before and after the @ symbol
df['From'] = df['From'].apply(lambda x: x.split('@')[0])

# %%
# Remove underscore, dashes, dots in the middle of string 
df['From'] = df['From'].str.replace('_', ' ')
df['From'] = df['From'].str.replace('-', ' ')
df['From'] = df['From'].str.replace('.', ' ')
df['From'] = df['From'].str.replace('+', '')

# %%
# Print all the unique values in the from column
df['From'].unique()
# Out:
# array(['quincy', 'updates', 'hello', 'do not reply', 'news', 'no reply',
#        'mipa', 'welcome', 'noreply', 'info', 'donasi', 'support', 'learn',
#        'indonesian personalized digest', 'inspiration', 'marketing',
#        'security', 'adminland space', 'netacademail',
#        'worldhistory space', 'notifications noreply', 'edx', 'taco',
#        'invitations', 'english personalized digest', 'notifications',
#        'kamran', 'curiosity noreply', 'noreply minato jf',
#        'lifeisbeautiful space', 'crew', 'humansinstructions space',
#        'indihome', 'bankbri', 'chris', 'messages noreply', 'admin',
#        'googleplay noreply', 'noreplyfeedproxy', 'filsafatkiri space',
#        'sarah', 'event', 'chatango noreply', 'notifapp', 'nyt', 'hackers',
#        'sam brace', 'super support', 'lenreg id', 'registration',
#        'privacy', 'rifa', 'noreply turkiyeburslari', 'tikaartiwi',
#        'edward', 'memesarelife space', 'bangkit', 'harvardx news',
# ...

# %%
# Simplify the from column

df.loc[df['From'].str.contains('reply','noreply'), 'From'] = 'reply'
df.loc[df['From'].str.contains('personal'), 'From'] = 'personal'
df.loc[df['From'].str.contains('space'), 'From'] = 'space'
df.loc[df['From'].str.contains('news'), 'From'] = 'news'

# %%
df.iloc[0:10]
# Out:
#       From                                            Subject  \
# 0   quincy  learn code apps chatgpt dall free hour javascr...
# 1  updates  myntra order item delivered please share feedback
# 2    hello                    japanese website look different
# 3    reply                                      surprise gift
# 4     news                                     upgrade saving
# 5    reply                                     security alert
# 6     mipa  delivered message permohonan terjemahan dokume...
# 7    hello  agung premananda amazing study abroad opportunity
# 8  welcome                   sosok bilal bin rabah nanganumba
# 9    reply                                ovo payment receipt
#
#                                                 Body  Day       Label
# 0  week five freecodecamp resource worth time fre...  Sat     updates
# 1  hello premananda nayak delivered order advance...  Sun        spam
# 2  image header japanese website analyze design c...  Thu  promotions
# ...

# %%
# Change the data type of each column to string
df['From'] = df['From'].astype(str)
df['Subject'] = df['Subject'].astype(str)
df['Body'] = df['Body'].astype(str)
df['Label'] = df['Label'].astype(str)
df['Day'] = df['Day'].astype(str)

# Concatenate the From, Subject, and Body columns into a new column called "Message"
df['Message'] = df['From'] + ' ' + df['Subject'] + ' ' + df['Day'] + ' ' + df['Body']

# Drop the From, Subject, and Body columns
df = df.drop(['From', 'Subject', 'Body', 'Day'], axis=1)

# %%
print(df.dtypes)
# Out:
# Label      object
# Message    object
# dtype: object

# %%
# Split data into training and testing set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df['Message'], df['Label'], test_size=0.2, random_state=42)

# %%
# Bag of Words
from sklearn.feature_extraction.text import CountVectorizer

count_vect = CountVectorizer()

X_train_counts = count_vect.fit_transform(X_train)

X_train_counts.shape

# TF-IDF
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer()

X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

X_train_tfidf.shape
# Out:
# (863, 29239)

# %%
# Define paramter grid for Naive bayes
param_grid_nb = {'alpha': [0.01, 0.1, 1, 10, 100]}

# Define paramter grid for logistic regression
param_grid_lr = {'C': [0.01, 0.1, 1, 10, 100]}

# Define paramter grid for SVM
param_grid_svm = {'C': [0.01, 0.1, 1, 10, 100]}

# Define paramter grid for random forest
param_grid_rf = {'n_estimators': [10, 100, 1000]}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Naive Bayes
from sklearn.naive_bayes import MultinomialNB

nb_classifier = MultinomialNB(alpha=0.1)

nb_classifier.fit(X_train_tfidf, y_train)

# Predict the labels
pred = nb_classifier.predict(count_vect.transform(X_test))

# Evaluate the model

print('Accuracy score: ', accuracy_score(y_test, pred))
print('Precision score: ', precision_score(y_test, pred, average='weighted'))
print('Recall score: ', recall_score(y_test, pred, average='weighted'))
print('F1 score: ', f1_score(y_test, pred, average='weighted'))

# Area under the ROC curve
from sklearn.metrics import roc_auc_score

# Compute predicted probabilities: y_pred_prob
y_pred_prob = nb_classifier.predict_proba(count_vect.transform(X_test))

# Compute and print AUC score
print("AUC: {}".format(roc_auc_score(y_test, y_pred_prob, multi_class='ovr')))
print(y_pred_prob)
# Out:
# Accuracy score:  0.7824074074074074
# Precision score:  0.7737937767699672
# Recall score:  0.7824074074074074
# F1 score:  0.7622584284824748
# AUC: 0.8159674371791119
# [[4.98015821e-094 1.00000000e+000 1.69591751e-096 1.72692695e-082
#   3.70142255e-024]
#  [2.18452709e-075 1.00000000e+000 1.85125115e-075 1.90257454e-067
#   3.92026415e-044]
#  [7.55341058e-060 2.19121464e-040 2.23493095e-070 6.72893041e-063
#   1.00000000e+000]
#  ...
#  [0.00000000e+000 5.41575198e-082 0.00000000e+000 0.00000000e+000
#   1.00000000e+000]
#  [5.12430766e-035 1.00000000e+000 6.20498985e-038 2.44806213e-038
#   1.01759047e-021]
#  [5.72604361e-144 4.50597066e-138 1.00000000e+000 1.05311852e-145
#   1.65251040e-074]]
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Create the pipeline
pipe = Pipeline([('scaler', StandardScaler(with_mean=False)), ('logreg', LogisticRegression(max_iter=10000))])

# Fit the pipeline to the training data
pipe.fit(X_train_tfidf, y_train)

# Create the transform
X_test_counts = count_vect.transform(X_test)

# Predict the labels: pred
pred = pipe.predict(X_test_counts)

# Evaluate the model

print('Accuracy score: ', accuracy_score(y_test, pred))
print('Precision score: ', precision_score(y_test, pred, average='weighted'))
print('Recall score: ', recall_score(y_test, pred, average='weighted'))
print('F1 score: ', f1_score(y_test, pred, average='weighted'))
# Out:
# Accuracy score:  0.8148148148148148
# Precision score:  0.8249374965383738
# Recall score:  0.8148148148148148
# F1 score:  0.8149245678602055

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=1000, random_state=0)

# Fit the classifier to the training data
rf.fit(X_train_tfidf, y_train)

# Predict the labels: pred
pred = rf.predict(X_test_counts)

# Evaluate the model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print('Accuracy score: ', accuracy_score(y_test, pred))
print('Precision score: ', precision_score(y_test, pred, average='weighted'))
print('Recall score: ', recall_score(y_test, pred, average='weighted'))
print('F1 score: ', f1_score(y_test, pred, average='weighted'))
# Out:
# Accuracy score:  0.7314814814814815
# Precision score:  0.7340134983552858
# Recall score:  0.7314814814814815
# F1 score:  0.7302876723697838
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# SVM
from sklearn.svm import SVC

# Create a SVC classifier
svc = SVC(kernel='linear', random_state=0)

# Fit the classifier to the training data
svc.fit(X_train_tfidf, y_train)

# Predict the labels: pred
pred = svc.predict(X_test_counts)

# Evaluate the model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print('Accuracy score: ', accuracy_score(y_test, pred))
print('Precision score: ', precision_score(y_test, pred, average='weighted'))
print('Recall score: ', recall_score(y_test, pred, average='weighted'))
print('F1 score: ', f1_score(y_test, pred, average='weighted'))
# Out:
# Accuracy score:  0.8009259259259259
# Precision score:  0.796833064949007
# Recall score:  0.8009259259259259
# F1 score:  0.7924173805049314

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.exceptions import ConvergenceWarning
import warnings

def run_grid_search(model, param_grid):
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        
        if isinstance(model, LogisticRegression):
            model = LogisticRegression(max_iter=1000)
        elif isinstance(model, LinearSVC):
            model = LinearSVC(max_iter=1000)
        
        if isinstance(model, LogisticRegression) or isinstance(model, LinearSVC):
            scaler = StandardScaler(with_mean=False)
            X_train_scaled = scaler.fit_transform(X_train_tfidf)
            grid_search = GridSearchCV(model, param_grid, cv=5, return_train_score=True)
            grid_search.fit(X_train_scaled, y_train)
        else:
            grid_search = GridSearchCV(model, param_grid, cv=5, return_train_score=True)
            grid_search.fit(X_train_tfidf, y_train)

    print(grid_search.best_params_)
    print(grid_search.best_score_)
    print(grid_search.best_estimator_)

# Perform grid search for Naive Bayes
run_grid_search(MultinomialNB(), param_grid_nb)

# # Perform grid search for Logistic Regression
# run_grid_search(LogisticRegression(), param_grid_lr)

# Perform grid search for SVM
run_grid_search(LinearSVC(), param_grid_svm)

# # Perform grid search for Random Forest
# run_grid_search(RandomForestClassifier(), param_grid_rf)
# Out:
# {'alpha': 0.1}
# 0.7648003763946767
# MultinomialNB(alpha=0.1)
# {'C': 0.01}
# 0.772872697943272
# LinearSVC(C=0.01)

# %%
# # Save the model
# import pickle

# pickle.dump(logreg, open('model.pkl', 'wb'))

# %%
# # Load the model
# model = pickle.load(open('model.pkl', 'rb'))

# # Predict the labels
# y_pred = model.predict(X_test)

# # Evaluate the model
# print('Accuracy score: ', accuracy_score(y_test, y_pred))
# print('Confusion matrix: \n', confusion_matrix(y_test, y_pred))
# print('Classification report: \n', classification_report(y_test, y_pred))
